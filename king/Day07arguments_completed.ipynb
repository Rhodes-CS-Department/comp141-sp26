# %% [markdown]
# # Lab Solutions

# %%
# 1. Day of the Week - this program takes an integer between 1-7 and outputs the corresponding day of week
# Note that 1 = Monday and the program outputs an error message if the user inputs anything other than 1-7.

day = int(input("Enter the day of week as a number (1-7): "))

if day == 1:
    print("It is Monday!")
elif day == 2:
    print("It is Tuesday!")
elif day == 3:
    print("It is Wednesday!")
elif day == 4:
    print("It is Thursday!")
elif day == 5:
    print("It is Friday!")
elif day == 6:
    print("It is Saturday!")
elif day == 7:
    print("It is Sunday!")
else:
    print("That is not a valid option.")

# %%
# 2. Tax Calculator

# assume only single and married (jointly filing)
# assume flat tax rate, first four tax brackets

status = input("What is your filing status? (Single, Married) ")
income = int(input("What is your income? "))
if status == "Single":
    if income <= 100525:
        taxes = income * 0.10
    else:
        taxes = income * 0.24
elif status == "Married":
    if income <= 201050:
        taxes = income * 0.10
    else:
        taxes = income * 0.24
print("Your taxes are $" + str(taxes))

# %%
# 3. Voter-eligibility by age

print("Let's see if you are age eligible to participate in the upcoming U.S. presidential election.")

month = 1
day = 31
year = 2025
bmonth = int(input("Month you were born (1-12): "))
bday = int(input("Day of month you were born (1-31): "))
byear = int(input("Year you were born (ex: 2001): "))

ageOnElectionDay = year - byear
if bmonth > month or (bmonth == month and bday > day): #birthday has yet to come
    ageOnElectionDay = ageOnElectionDay - 1 #you can also write this as ageOnElectionDay -= 1

if ageOnElectionDay >= 18:
    print("You will be", ageOnElectionDay, "on Jan 31, 2025, so be sure to get out and cast your vote!")
else:
    print("Sorry, you will only be ", ageOnElectionDay, "on Jan 31, 2025, so you are not eligible to vote.")

# %%
# 4. MLGW needs your help!

num_gallons = int(input("Please enter the number of gallons of water used this month (integers only): "))

if num_gallons <= 8000:
    bill = 5 * num_gallons/1000
    rounded_bill = round(bill, 2)
    print("Your water bill this month is $", rounded_bill, ".", sep='')
    
elif num_gallons <= 22000: # i don't really understand if-elif
    bill = 6 * num_gallons/1000
    rounded_bill = round(bill, 2)
    print("Your water bill this month is $", rounded_bill, ".", sep='')
    
elif num_gallons > 22000 and num_gallons <= 30000:
    bill = 7 * num_gallons/1000
    rounded_bill = round(bill, 2)
    print("Your water bill this month is $", rounded_bill, ".", sep='')
    
else:
    bill = 10 * num_gallons/1000
    rounded_bill = round(bill, 2)
    print("Your water bill this month is $", rounded_bill, ".", sep='')

# %%
# alternatively, consider:
bill = 700 / 3

formatted_bill = format(bill, '.2f')
print(formatted_bill)

# %% [markdown]
# # Review: printing

# %%
# how to print things
# print syntax:
what_you_want_to_print = 'hello'
print() # prints a new line
print(what_you_want_to_print) # what_you_want_to_print is called an argument

thing1 = 10 # data type: int
thing2 = 'goodbye' # data type: string
thing3 = False # data type: boolean
print(thing1, thing2, thing3) # print can take multiple arguments, separates them with a space, can mix data types
print(what_you_want_to_print + thing2) # join "addable" things with a +, but you can't add strings and numbers

num1 = 10
num2 = 10
# want: 1010
print(str(num1) + str(num2)) # this is called string "concatenation"
new_string = str(num1) + str(num2) # string concatenation

new_num = 5 * int(new_string) # we can convert strings to ints (or floats!)
print(new_num)

# %% [markdown]
# # Day 9: Arguments and Parameters
# __Argument:__ piece of data that is sent into a function
# * Function can use argument in calculations
# * When calling the function, the argument is placed in parentheses following the function name
#
# __Parameters:__ variable that is assigned the value of an argument when the function is called
#
# In the example below, we are not using any arguments or parameters. Without them, it is impossible to send information from one function to another.

# %%
# functions and main()
## try to put all of your code either in a main() function or in a function that main() will call
## ex:
def main():
    print("i, the main function, am doing everything!")
    round(3.222, 2)
    int("13")
    input("Hello!" )
main()

# %%
## ex:
def helper():
    print('now I\'M doing everything') # \ is an escape character

def main():
    print('i only call a helper!')
    helper() # here we are CALLING helper

main()
# what a function is: reusuable block of code
# how to call a function: function_name()

# %%
# This program is supposed to greet you by name, but it
# does not work!

def greetings():
    print("Hello,", name)


def main():
    name = input("What is your name? ") # this variable has LOCAL SCOPE and is local ONLY to main()
    greetings()

main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       9     name = input("What is your name? ") # this variable has LOCAL SCOPE and is local ONLY to main()
#      10     greetings()
# ---> 12 main()
#
# Cell In[1], line 10, in main()
#       8 def main():
#       9     name = input("What is your name? ") # this variable has LOCAL SCOPE and is local ONLY to main()
# ---> 10     greetings()
#
# Cell In[1], line 5, in greetings()
#       4 def greetings():
# ----> 5     print("Hello,", name)
#
# NameError: name 'name' is not defined

# %%
#This program is supposed to greet you by name, and we will fix it!

def greetings(): # defines the function
    print("Hello,", name) # name is not defined


def main():
    name = input("What is your name? ") # this variable has LOCAL SCOPE and is local ONLY to main()
    greetings() # call greetings

main() # call main
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       8     name = input("What is your name? ") # this variable has LOCAL SCOPE and is local ONLY to main()
#       9     greetings() # call greetings
# ---> 11 main() # call main
#
# Cell In[2], line 9, in main()
#       7 def main():
#       8     name = input("What is your name? ") # this variable has LOCAL SCOPE and is local ONLY to main()
# ----> 9     greetings()
#
# Cell In[2], line 4, in greetings()
#       3 def greetings(): # defines the function
# ----> 4     print("Hello,", name)
#
# NameError: name 'name' is not defined

# %%
# another solution, legal but discouraged
global_name = input("What is your name? ") # the scope of this variable is GLOBAL, meaning it can be accessed anywhere
# variables defined out of functions are GLOBAL
# this is discouraged because of "side effects"

def greetings():
    print("Hello", global_name)

def main():
    greetings()

main()

# %% [markdown]
# __Functions can accept multiple arguments__
# * Parameter list replaces single parameter
# * Parameter list items separated by comma
# * Arguments are passed by position to corresponding parameters (First parameter receives value of first argument, second parameter receives value of second argument, etc.)
# * When a function is called, all the values inside the parenthesis from the calling line are __immediately copied__ into the variables given in the function definition.
# * The values being copied from the calling function are called __arguments__.
# * The variables being copied into are called __parameters__.
#
# ![function_Example2.png](attachment:function_Example2.png)
#
# __Scope of a variable__: variables (including parameters) have a scope, meaning the part of a program in which a variable may be accessed
# * __Local variable:__ belongs to the function in which it is defined (also called function scope)
# * __Global variable:__ the entire program has access to this variable (Don't use these!)
# * Scope of a parameter: the function in which the parameter is used (local)
#
# __Local Variables__:
# * A local variable cannot be accessed by statements inside its function which precede its creation
# * Different functions may have local variables with the same name
# * Each function does not see the other function’s local variables, so no confusion

# %%
#Description: This program 'sings' Happy birthday to you and your twin
#Input: Your name and your twin's name
#Output: Happy birthday song for both you and your twin.

def greetings(name):
    print("Hello,", name)


def main():
    name = input("Enter the first name: ")
    greetings(name)
    name = input("Enter the second name: ")
    greetings(name)

main()
# Out:
# Hello, Jace
# Hello, Jessie

# %% [markdown]
# * There is no permanent link between the variable `name`
# * Changes made to a parameter value within the function do not affect the argument
# * Arguments and Parameters provide a way for one-way-only communication between one function and another function
# * Calling function can communicate with called function
# * We will learn later how to get information from the called function back to the calling function.

# %%
# Let's trace this code and determine what the output will be before we run it.
def called(x):
    print("From called:", x)
    x = 10
    print("From called, after changing x:", x)

def caller():
    x = 5
    print("From caller:", x)
    called(x)
    print("From caller, after calling called:", x)

caller()

# %%
#Trace through the following tricky example by hand and predict 
#the output before running the code

def mystery(x, z, y):
    print(z, y-x)

def main():
    x = 9
    y = 2 
    z = 5
    mystery(z, y, x)
    mystery(y, x, z)
    mystery(x+z, y-x, y)
# main: (9, 2, 5)

# mystery (1st time): (5, 2, 9)
# mystery (2nd time): (2, 9, 5)
# mystery (3rd time): (14, -7, 2)

# output:
# 2 4
# 9 3
# -7 -12
main()
# Out:
# 2 4
# 9 3
# -7 -12

# %% [markdown]
# # Try it
#
# Write your own function. Name it anything. Give it as many arguments as you want, named whatever you want. Make your function *do something*. Write a main function which calls your function.

# %%
# write a function here and call it in main!
def do_something_yourself(argument_good, argument_bad, argument_ugly):
    print(argument_bad, argument_ugly)

def main():
    do_something_yourself(10, 20, 40)

main()
# Out:
# 20 40

# %% [markdown]
# __Recap__
# * There is no permanent connection between the `x` in caller and the `x` in called.
# * Arguments are passed **one way only** from caller to called when caller calls called.
# * This copies caller’s value of `x` into called’s `x`.
# * Any assignments to `x` inside of called do not come back to caller.
#
#
# __Average.py using functions__
# * Using functions, write a program that prompts the user for 3 numbers and outputs the average of those numbers.
# * Each function should "do one thing". So if you want to 1) get user input, 2) compute the average, you should use two functions.

# %%
# write a function which computes the average of three numbers
def average(a, b, c):
    total = a + b + c
    print(total / 3)

# test that function in the cell below

# write a main function which asks the user for input
def main():
    average(30, 20, 30)
# call main()

# %%
# test your function here by calling it

# %%
def get_input(): #option 1
    var1 = input("What is your value?")
    # get input in the called function
    # how would you get this data out?

def use_input(var1):
    print("You said:", var1)

def main():
    value = input("What is your value?")
    use_input(value)
    # get the input in a CALLING function
    # and pass it in

# %% [markdown]
# ## Practice
# **collatz.py**
#
# Write a function called `collatz` which takes in one argument called `n`. If `n` is even, divide it by 2. If `n` is odd, multiply by 3 and add 1. Print out the new number.
#
# *Hint: `n % 2 == 0` checks whether `n` is even!*

# %%
# collatz

# %% [markdown]
# **activity.py**
#
# Write a function which takes in the type of weather outside (eg, hot, cool, cold, rainy, windy) and prints out a good activity for the day. Use if-elif-else statements, and call your function multiple times with different arguments.

# %%
# activity

# %% [markdown]
# ### Please do the following:
#
#
# * Project 2 - due in office hours next week
