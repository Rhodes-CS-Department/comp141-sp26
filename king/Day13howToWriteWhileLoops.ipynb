# %% [markdown]
# # Day 13: How to Write While Loops

# %% [markdown]
# ## Practice
# * Write a while loop that does the following:
# <ol>
#     <li>asks the user for 2 numbers </li>
#     <li>compares the numbers</li>
#     <li>outputs the bigger number</li>
#     <li>keeps going until the user enters a negative number</li>
# </ol>

# %%
def main():
    pass
        
main()

# %% [markdown]
# ## Modification as a class
# * Edit the previous loop so that it outputs the sum of the larger numbers when the loop finishes.

# %%
#Copy/Paste the code from above, and then we'll modify it 
def main():
    pass

main()

# %% [markdown]
# * Edit the previous loop so that it uses a **boolean variable** for the loop condition instead of an explicit condition
# * When using boolean variables, `my_boolean == True` is redundant and equivalent to `my_boolean`!

# %%
def main():
    number = 10
    keep_going = number > 0 # keep_going is a boolean variable

main()

# %% [markdown]
# ## You try
#
# Write a program below that uses a loop to repeatedly ask the user to type in an integer from the keyboard. Stop the loop when the number is between 1 and 10, inclusive.

# %%
# very similar to the above loop! feel free to copy and paste and modify as needed

# %% [markdown]
# ## Pseudo-code
# * Like code, but there is no strict syntax
# * Much faster than actual coding!

# %%
# real Python code
def my_function():
    name = input("What is your name?")
    x = float(input("A number: "))
    if x >= 0 and x <= 100:
        print("$%.2f" % x)

# pseudocode
# my_function:
#   name = get name from user
#   x = get number from user
#   if x is between 0 and 100:
#     print x with 2 decimal places

# %% [markdown]
# __To Write a While Loop__
# * Start with pseudocode
# * Define a condition in plain English, using a phrase like "while" or "until" or "as long as"
# * Describe what to do "while" the condition is true
# * Identify when/how the condition should be updated
# * Translate the pseudocode into code

# %%
# as long as the user wants to keep going:
#  ask the user for a new number
#  double the number
#  add 1 to the number
#  add the new number to a running total
# output the running total

# %%
# translate the pseudocode!

# %% [markdown]
# ## Generating Random Numbers
# * Random number are useful in a lot of programming tasks
# * `random` module: includes library functions for working with random numbers
# * `randint` function: generates a random number in the range provided by the arguments
#
# ![random.png](attachment:random.png)

# %%
# Using random numbers Example

#This program displays a random number between 1 and 10 (inclusive)
import random

def main():
    #Get a random number
    number = random.randint(1, 10)
  
    #Display the number
    print("The number is", number)

main()

# %% [markdown]
# ## Practice
# Using the pseudocode below, write a "Guess that Number" game
#
# __Pseudocode for Guess the Number Game__
# ```
# number = generate a random number between 1 and 100
# guess = ask user to guess a number between 1 and 100
# if number does not equal guess, then keep going
# if guess is greater than number, tell user this
# else if guess is less than number, tell user this
# guess = ask user to guess a number between 0 and 100
# if number does not equal guess, then keep going
# if guess is greater than number, tell user this
# else if guess is less than number, tell user this
# guess = ask user to guess a number between 0 and 100
# if number does not equal guess, then keep going
# if guess is greater than number, tell user this
# else if guess is less than number, tell user this
# . . .
# When user guesses correct number, tell them so
# ```
#
# Here's a Sample Output for the Program:
# ```
# Guess a number between 1 and 100: 50
# Your guess was too high.
# Please try again: 40
# Your guess was to high.
# Please try again: 30
# Your guess was too low.
# Please try again: 35
# You guessed correctly! Great work!
# ```

# %%
#Guess that Number Game 
import random

# STEPS:
# make a random number (see above code!) 
# ask the user to guess it (see above code!)
# if they're wrong, give them a hint
# if they're right, break out of the loop and congratulate them

# %% [markdown]
# ## More practice
# Try these problems:
#
# Write a program that asks the user to type in two integers, over and over again. Print the sum of the two integers. Make the loop stop when the second integer is less than zero (and don’t print the sum in this case).
#
# a. Change the loop so the sum is printed when the second integer is less than zero.
#
# b. Make the loop stop when the sum of the two integers is odd. (try it both with printing the sum and not printing).
#
# c. Make the loop stop when the first integer is less than zero (and then don’t ask for the second one).

# %%
#Practice space

# %%
#Practice space

# %%
#Practice space

# %% [markdown]
# ### Calculate a running average
#
# Write a while loop that asks the user to input numbers until the number input is -1. In each iteration *accumulate* the sum (of the numbers entered so far) and *increment* the count (of the numbers entered so far).
#
# a. Print the final average *after* the while loop terminates
#
# b. Print the *running average* in each iteration. The *running average* for a series of numbers is the average of the number seen so far.

# %%
# running average

# %% [markdown]
# Please do the following:
# * Project 4 and 5 due in office hours the week of Feb 23
# * Special classes next Wednesday and Friday
