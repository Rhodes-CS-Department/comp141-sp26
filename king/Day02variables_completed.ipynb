# %% [markdown]
# ## Day 2: Variables
# Soon you'll do a lab that expands your understanding of Jupyter notebooks. For now, remember: `Shift + Enter` runs a cell.
#
# Most computer programs perform three main steps.
#
# __Step 1:__ Receive input  (any data that the program receives while it is running)
#
# __Step 2:__ Perform some process on the input (Example: mathematical calculation)
#
# __Step 3:__ Produce output

# %% [markdown]
# ### Displaying Output with the `print` Function
# * __Function:__ piece of prewritten code that performs an operation
# * __Argument:__ data given to a function
# * Statements in a program execute in the order that they appear (from top to bottom)
# * Example: `print("Hello World")`
#
# `print` is a built-in function in Python that will display output. Whatever you put inside the parenthesis, will be displayed.

# %%
print("Hello World") # function_name(arg1) is how you call a function called function_name with argument arg1
print(1+2+3) # this CALLS print with an argument 6 (EVALUATION of 1+2+3)

# %% [markdown]
# In the following cell, write Python code to do the following.
# * Write a statement that displays your name.
# * Write a statement that displays “I am 100 years old!”
# * Write a statement that displays the value of multiplying 322 * 35.

# %%
print("Jace") # "Jace" (with quotes) is a STRING
print(3000)
print("I am 100 years old!")
# Out:
# Jace
# 3000
# I am 100 years old!

# %% [markdown]
# ## Comments
# * Notes of explanation within a program
# * Ignored by Python interpreter
# * Intended for a person reading the program’s code
# * Begin with a # character
#
# The following cell is an example. Feel free to run it yourself as I am demoing.

# %%
# Jace King # comments are ignored by the python "interpreter"
# COMP 141
# This program display's a person's name and address.

'''
This is a "block comment"
'''
# Printing name and address here
print("Jace King")
print("123 Main Street") #Address starts here
print("Memphis, TN 38104")

print("Jace King")
print("123 Main Street") #Address starts here
print("Memphis, TN 38104")
# Out:
# Jace King
# 123 Main Street
# Memphis, TN 38104

# %%
# a little calculation in Python
# how much time can you save in a year if you use Ctrl+C and Ctrl+V 
# instead of right click copy right click paste?
time_ctrl_c = 0.1 # second
time_right_click_copy = 3 # seconds
num_ctrl_c_in_a_day = 15 * 3 # 15 copies per hour for 3 hours of coding?
time_spent_ctrl_c_in_a_year = 200 * num_ctrl_c_in_a_day * time_ctrl_c
print(time_spent_ctrl_c_in_a_year / 60)
time_spent_right_click_copying_in_a_year = 200 * num_ctrl_c_in_a_day * time_right_click_copy
print(time_spent_right_click_copying_in_a_year / 60 / 60)
# Out:
# 15.0
# 7.5

# %% [markdown]
# ## Variables
# __Variable:__ name that represents a value stored in the computer memory
# * Used to access and manipulate data stored in memory
# * A variable references the value it represents
#
# __Assignment statement:__ used to create a variable and make it reference data
# * General format is variable = expression
# * Example: `age = 29`
# * __Assignment operator:__ the equal sign (=)
#
# __Info about variables:__
# * In assignment statements, variable receiving value must be on __left__ side
# * A variable can be passed as an argument to a function
# * Variable names should not be enclosed in quote marks
# * You can only use a variable if a value is assigned to it
#
# __Variable Naming Rules:__
# * Variable names cannot be a Python key word
# * Variable names cannot contain spaces
# * First character must be a letter or an underscore
# * After first character may use letters, digits, or underscores
# * Variable names are case sensitive
# * Variable names should reflect its use!
#
# __Displaying Multiple Items with the `print` Function__
# * Python allows one to display multiple items with a single call to print
# * Items are separated by commas when passed as arguments
# * Arguments are displayed in the order they are passed to the function
# * Items are automatically separated by a space when displayed on screen

# %%
dog_name = "Bea" # I prefer what is called snake_case_naming_convention for variables
# as opposed to CamelCaseNamingConvention, which is only for special situations in Python
print("My dog's name is", dog_name) # we are PASSING dog_name into print when we CALL it

# this is called a variable ASSIGNMENT
age = 29 # = in Python is ASSIGNMENT, not EQUALITY

# %% [markdown]
# **Comments and Names**
# * Give things *descriptive* and *clear* names. Don't abbreviate!
# * Code with good names is "self-commenting", meaning the names *are* the comments
# * For now, practice good names and excessive commenting.

# %%
# example of bad naming
p = 8 # projects in the semester
t = 6 # time spent on each project
s = p * t # total time on all projects

# example with good naming
projects = 8
time_per_project = 6
total_time = projects * time_per_project
print(total_time) # printing is your #1 tool for figuring out what your code is doing
# Out:
# 48

# %% [markdown]
# ## Data Types
# Categorize value in memory
# * Integers (`int`) - whole numbers; may be negative
# * Floats (`float`) - any number with a decimal point; may be negative
# * Strings (`str`) - Any sequence of letters, numbers, or punctuation.
#
# Some operations behave differently depending on data type

# %%
# integers vs string variable types
a = 5
b = 7
print(a + b)
print(a * 5)
  
a = "5"
b = "7"
print(a+b) # concatenation
print(a * 5) # reduplicates the string 5 times

# floating point numbers
a = 7.000000123
b = 100000000.3
print(round(a + b, 10))
c = 7e10
print(c)
# Out:
# 12
# 25
# 57
# 55555
# 100000007.30000012
# 70000000000.0

# %% [markdown]
# A variable in Python can refer to items of any type
#
# __You can reuse a variable name in Python, but doing that will overwrite the old value with the new value.__

# %%
x = 90
print(x)
x = "Take me to your leader"
print(x)

# %% [markdown]
# ## Getting input from the user
#
# * Most programs need to read input from the user
# * Built-in `input` function reads input from keyboard
# * Returns the data as a string
# * Format: `variable = input(prompt)` (__prompt__ is typically a string instructing user to enter a value)
# * Does not automatically display a space after the prompt
# * Example:
# `name = input("Please enter your name: ")`

# %%
name = input("Please enter your name: ") # user input
age = 30
print("Your name is", name, 1, 2, 3, 4, 5, "hello", "goodbye")
print("Your age is", age)
# Out:
# Your name is Jace 1 2 3 4 5 hello goodbye
# Your age is 30

# %%
# try getting the number of siblings from the user as input
num_siblings = input("How many siblings do you have?")
print("Wow, so you have", num_siblings, "siblings?!")
# Out:
# Wow, so you have 10 siblings?!

# %%
num_siblings_1 = input("How many?")
num_siblings_2 = input() # prompt is unnecessary
print("Total Siblings:", num_siblings_1 + num_siblings_2) # the result of an input is ALWAYS a STRING
# Out:
# Total Siblings: 48

# %% [markdown]
# ## Reading Numbers with the input Function
#
# * `input` function always returns a string
#
# Python has built-in functions to convert between data types
# * `int(item)` converts item to an int
# * `float(item)` converts item to a float
#
# __Nested function call:__ general format: `function1(function2(argument))`
# * value returned by function2 is passed to function1
# * Type conversion only works if item is valid numeric value, otherwise, throws exception
#
# __Input from Keyboard:__
# * For integers: `variable = int(input("Prompt"))`
# * For ﬂoats: `variable = float(input("Prompt"))`
# * For strings: `variable = input("Prompt")`

# %%
#Prompt the user for their age
age = int(input("How old are you? "))

print("You will be", age+1, "on your next birthday.")
# Out:
# You will be 26 on your next birthday.

# %% [markdown]
# Please do the following:
# 1. Lab 00 (lab00) - due by the beginning of next class

# %% [markdown]
# **Practice:**
# 1. Create a variable which stores the result of a mathematical operation (`+`, `-`, `*`, `/`).
# 2. Display the value of that variable using the `print` function.
# 3. Create a variable which stores a string.
# 4. Display the value of that variable.
# 5. Create a variable which stores a user input using the `input` function.
# 6. Display the value of that variable.
# 7. Repeat that, storing a user input, but this time, make sure the user input is numeric (eg, 7, 3.5, etc). Can you do math on that variable? In other words, if the user inputs `7`, can you produce `35` by multiplying the user input by `5`?
# 8. Can you determine what `type` a user input is?

# %%
# Practice
