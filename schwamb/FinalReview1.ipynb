# %% [markdown]
# # We did it!! We made it through all the content of COMP141
# ## Final Review
# - Variables
# - Functions
# - Conditionals (if/elif/else)
# - Loops (for/while)
# - Nested loops
# - Lists
# - Strings
# - File I/O
# -
